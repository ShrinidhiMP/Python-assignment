# %% [markdown]
# ##                              ** ASSIGNMENT-1 **

# %% [markdown]
# Task1] Go through some of the other in built functions.
# soln: There are 67 in built functions in Python.
#       some of them are
#       1.any()-returns true if any item in an iterable object is true.
#       2.bin()-returns the binary version of a number.
#       3.bytes()-returns a bytes object.
#       4.compile()-returns the specified source as an object,ready to be executed
#       5.divmod()-returns the quotient and the reminder when argument1 is diveded
#                   by argument2.
#       6.eval()-evaluates and executes an expression.
#       7.format()-formats a specified value.
#       8.globals()-returns the current global symbol table as a dictionary.
#       9.help()-executes the built in help system.
#       10.issubclass()-returns true if a specified class is a subclass of
#                       a specified object.
#
# Task2] Given string is str1="welcome to pythone"
#         check if 'to' is present in "welcome to pythone".
# soln: find() is used to find any substring is present in a
#       string.

# %%
str1="welcome to python"
result=str1.find('to')
print("substring 'to':",result)
# Out:
# substring 'to': 8
