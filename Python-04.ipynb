# %% [markdown]
# TASK-7
# Go through other inbuilt methods like
#
# 1] difference() -
#    The diggerence between the two sets in python is equal to the difference between the number of elements in two sts.The function difference() returns a set that is the difference between two sets.
#    syntax- difference(set)
#
# 2] symmetric_difference() -
#    This method returns set that contains all items from both set,but no the items that are present in both set.
#    syntax-  symmetric_diffrence(set)
#
# TASK-8
# Mask a table of all the In-built data structures and point out the differences one by one.
#
# 1] list()- stores data of different data type in sequential manner.
#             e.g.,[1,2,'hi',2.3]
#
# 2] dictionary()- stores key-value pairs.
#                   e.g.,{1:'Python',2:'Maths'}
#
# 3] tuple()- same as lists,but with the exception that the data once entered
#             into this cannot be changed.
#             e.g.,my_tuple=(1,2,3)
#
# 4] sets()- collection  of unordered elements that are unique.If the data is
#             repeated, it would be entered into set only once.
#             e.g.,my_set={1,2,3,4,5,5}
#             output- {1,2,3,4,5}
